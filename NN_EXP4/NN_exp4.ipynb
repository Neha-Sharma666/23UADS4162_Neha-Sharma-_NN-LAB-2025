# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os

# Print the path to confirm
print("Google Drive Mounted Path:", os.listdir('/content/drive'))
# Out:
# Google Drive Mounted Path: ['MyDrive', '.shortcut-targets-by-id', '.file-revisions-by-id', '.Trash-0', '.Encrypted']

# %%
import tensorflow as tf
import numpy as np
import time
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
import os


drive_path = "/content/drive/MyDrive/NN_Hyperparameter_Results/"

if not os.path.exists(drive_path):
    os.makedirs(drive_path)


output_file = os.path.join(drive_path, "nn_hyperparameter_results.xlsx")


if not os.path.exists(output_file):
    results = pd.DataFrame(columns=[
        "Configuration No.", "Output", "Loss Curve", "Accuracy Curve"
    ])
    results.to_excel(output_file, index=False)
    print(f"Excel file initialized: {output_file}")

# Disable eager execution for TensorFlow v1 compatibility
tf.compat.v1.disable_eager_execution()

# Loading MNIST dataset
(X_train, y_train), (X_test, y_test) = tf.keras.datasets.mnist.load_data()
X_train, X_test = X_train / 255.0, X_test / 255.0  # Normalize

#  Reshape into vectors
X_train = X_train.reshape(-1, 28 * 28)
X_test = X_test.reshape(-1, 28 * 28)

# One-hot encode the labels
y_train = np.eye(10)[y_train]
y_test = np.eye(10)[y_test]

#Hyperparameters
learning_rate = 0.1
epochs = 50
batch_size = 10

#  Hyperparameter combinations
activations = ['relu', 'sigmoid', 'tanh']
hidden_layers = [256, 128, 64]

# Function to create and train the model
def train_and_evaluate(X_train, y_train, X_test, y_test, activation, hidden_layer_size, lr, bs, ep):
    tf.compat.v1.reset_default_graph()

    # Placeholders
    X = tf.compat.v1.placeholder(tf.float32, [None, 28 * 28])
    Y = tf.compat.v1.placeholder(tf.float32, [None, 10])

    # Hidden layer
    W1 = tf.Variable(tf.random.normal([28 * 28, hidden_layer_size]))
    b1 = tf.Variable(tf.random.normal([hidden_layer_size]))

    if activation == "relu":
        hidden_output = tf.nn.relu(tf.matmul(X, W1) + b1)
    elif activation == "sigmoid":
        hidden_output = tf.nn.sigmoid(tf.matmul(X, W1) + b1)
    elif activation == "tanh":
        hidden_output = tf.nn.tanh(tf.matmul(X, W1) + b1)

    # Output layer
    W2 = tf.Variable(tf.random.normal([hidden_layer_size, 10]))
    b2 = tf.Variable(tf.random.normal([10]))

    logits = tf.matmul(hidden_output, W2) + b2
    loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=Y))

    optimizer = tf.compat.v1.train.GradientDescentOptimizer(learning_rate=lr).minimize(loss)

    # Accuracy calculation
    correct_pred = tf.equal(tf.argmax(logits, 1), tf.argmax(Y, 1))
    accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32))

    # Training
    init = tf.compat.v1.global_variables_initializer()

    loss_curve = []
    acc_curve = []

    start_time = time.time()

    with tf.compat.v1.Session() as sess:
        sess.run(init)

        num_batches = len(X_train) // bs
        for epoch in range(ep):
            for i in range(num_batches):
                batch_x = X_train[i * bs:(i + 1) * bs]
                batch_y = y_train[i * bs:(i + 1) * bs]
                sess.run(optimizer, feed_dict={X: batch_x, Y: batch_y})

            # Loss and accuracy for each epoch
            epoch_loss, epoch_acc = sess.run([loss, accuracy], feed_dict={X: X_train, Y: y_train})

            loss_curve.append(epoch_loss)
            acc_curve.append(epoch_acc)

            print(f"Epoch {epoch + 1}/{ep}, Loss: {epoch_loss:.4f}, Accuracy: {epoch_acc:.4f}")

        # Test accuracy and confusion matrix
        test_acc = sess.run(accuracy, feed_dict={X: X_test, Y: y_test})
        predictions = sess.run(tf.argmax(logits, 1), feed_dict={X: X_test})
        true_labels = np.argmax(y_test, axis=1)

        conf_matrix = confusion_matrix(true_labels, predictions)
        execution_time = time.time() - start_time


        plt.figure(figsize=(12, 5))

        # Loss curve
        plt.subplot(1, 2, 1)
        plt.plot(loss_curve, label='Loss', color='blue')
        plt.title(f"Loss Curve - {activation} - {hidden_layer_size}")
        plt.xlabel("Epochs")
        plt.ylabel("Loss")
        plt.legend()
        loss_curve_img = f"{drive_path}loss_{activation}_{hidden_layer_size}.png"
        plt.savefig(loss_curve_img)

        # Accuracy curve
        plt.subplot(1, 2, 2)
        plt.plot(acc_curve, label='Accuracy', color='green')
        plt.title(f"Accuracy Curve - {activation} - {hidden_layer_size}")
        plt.xlabel("Epochs")
        plt.ylabel("Accuracy")
        plt.legend()
        acc_curve_img = f"{drive_path}accuracy_{activation}_{hidden_layer_size}.png"
        plt.savefig(acc_curve_img)

        plt.close()


        output_text = (
            f"Results for Combination:\n"
            f"Activation: {activation}\n"
            f"Hidden Layer: {hidden_layer_size}\n"
            f"Test Accuracy: {test_acc:.4f}\n"
            f"Execution Time: {execution_time:.2f} sec\n"
            f"Confusion Matrix:\n{conf_matrix}"
        )


        print("\n" + output_text + "\n")

        return {
            "output": output_text,
            "loss_curve": loss_curve_img,
            "accuracy_curve": acc_curve_img
        }

# Iterating through all combinations
config_no = 1
for activation in activations:
    for hidden_layer in hidden_layers:
        print("\n--------------------------------------------------")
        print(f"Training with Activation: {activation}, Hidden Layer: {hidden_layer}")
        print(f"Learning Rate: {learning_rate}, Batch Size: {batch_size}, Epochs: {epochs}")
        print("--------------------------------------------------")

        results_dict = train_and_evaluate(
            X_train, y_train, X_test, y_test,
            activation, hidden_layer, learning_rate, batch_size, epochs
        )


        if os.path.exists(output_file):
            results = pd.read_excel(output_file)
        else:
            results = pd.DataFrame(columns=[
                "Configuration No.", "Output", "Loss Curve", "Accuracy Curve"
            ])

        new_row = pd.DataFrame([{
            "Configuration No.": config_no,
            "Output": results_dict["output"],
            "Loss Curve": results_dict["loss_curve"],
            "Accuracy Curve": results_dict["accuracy_curve"]
        }])

        results = pd.concat([results, new_row], ignore_index=True)


        results.to_excel(output_file, index=False)

        config_no += 1

print("\n All combinations tested. Results are saved:", output_file)
# Out:
# --------------------------------------------------
# Training with Activation: relu, Hidden Layer: 256
# Learning Rate: 0.1, Batch Size: 10, Epochs: 50
# --------------------------------------------------
# Epoch 1/50, Loss: 0.4243, Accuracy: 0.9175
# Epoch 2/50, Loss: 0.2404, Accuracy: 0.9435
# Epoch 3/50, Loss: 0.1899, Accuracy: 0.9520
# Epoch 4/50, Loss: 0.1487, Accuracy: 0.9595
# Epoch 20/50, Loss: 0.1315, Accuracy: 0.9603
# Epoch 21/50, Loss: 0.1264, Accuracy: 0.9620
# Epoch 22/50, Loss: 0.1254, Accuracy: 0.9624
# Epoch 23/50, Loss: 0.1215, Accuracy: 0.9636
# Epoch 24/50, Loss: 0.1162, Accuracy: 0.9651
# Epoch 25/50, Loss: 0.1138, Accuracy: 0.9656
# Epoch 26/50, Loss: 0.1126, Accuracy: 0.9668
# Epoch 27/50, Loss: 0.1063, Accuracy: 0.9680
# Epoch 28/50, Loss: 0.1032, Accuracy: 0.9689
# Epoch 29/50, Loss: 0.0990, Accuracy: 0.9702
# Epoch 30/50, Loss: 0.0995, Accuracy: 0.9697
# Epoch 31/50, Loss: 0.0944, Accuracy: 0.9713
# Epoch 32/50, Loss: 0.0904, Accuracy: 0.9722
# Epoch 33/50, Loss: 0.0877, Accuracy: 0.9728
# Epoch 34/50, Loss: 0.0862, Accuracy: 0.9729
# Epoch 35/50, Loss: 0.0807, Accuracy: 0.9747
# Epoch 36/50, Loss: 0.0798, Accuracy: 0.9751
# Epoch 37/50, Loss: 0.0787, Accuracy: 0.9753
# Epoch 38/50, Loss: 0.0790, Accuracy: 0.9758
# Epoch 39/50, Loss: 0.0785, Accuracy: 0.9756
# Epoch 40/50, Loss: 0.0756, Accuracy: 0.9763
# Epoch 41/50, Loss: 0.0760, Accuracy: 0.9768
# Epoch 42/50, Loss: 0.0714, Accuracy: 0.9778
# Epoch 43/50, Loss: 0.0711, Accuracy: 0.9776
# Epoch 44/50, Loss: 0.0661, Accuracy: 0.9790
# Epoch 45/50, Loss: 0.0738, Accuracy: 0.9772
# Epoch 46/50, Loss: 0.0700, Accuracy: 0.9786
# Epoch 47/50, Loss: 0.0719, Accuracy: 0.9782
# Epoch 48/50, Loss: 0.0666, Accuracy: 0.9793
# Epoch 49/50, Loss: 0.0652, Accuracy: 0.9796
# Epoch 50/50, Loss: 0.0648, Accuracy: 0.9800
#
# ✅ Results for Combination:
# Activation: relu
# Hidden Layer: 64
# Test Accuracy: 0.9520
# Execution Time: 224.00 sec
# Confusion Matrix:
# [[ 966    0    3    0    1    3    3    1    2    1]
#  [   0 1118    1    2    1    1    1    2    9    0]
#  [   4    5  981    6    5    2    4    9   16    0]
#  [   3    1   10  922    1   47    0    6   13    7]
#  [   2    2    2    1  934    4    6    1    5   25]
#  [   3    1    0    6    0  854    7    1   15    5]
#  [  12    3    7    0    5   16  905    0   10    0]
#  [   1    3    9    2    5    0    1  990    2   15]
#  [   9    1   11   13    9    8    7    3  903   10]
#  [   6    4    4    5   19    7    1    5   11  947]]
#
#
# --------------------------------------------------
# Training with Activation: sigmoid, Hidden Layer: 256
# Learning Rate: 0.1, Batch Size: 10, Epochs: 50
# --------------------------------------------------
# Epoch 1/50, Loss: 0.3897, Accuracy: 0.9041
# Epoch 2/50, Loss: 0.2492, Accuracy: 0.9321
# Epoch 3/50, Loss: 0.1924, Accuracy: 0.9454
#
# ✅ Results for Combination:
# Activation: sigmoid
# Hidden Layer: 256
# Test Accuracy: 0.9574
# Execution Time: 385.00 sec
# Confusion Matrix:
# [[ 960    0    1    2    2    4    3    1    3    4]
#  [   0 1117    3    3    0    2    3    1    6    0]
#  [   5    1  983   12    4    1    3    9   14    0]
#  [   2    1   10  965    1   13    1    9    5    3]
#  [   0    0    6    2  942    0    1    6    1   24]
#  [   4    0    4   14    1  852    6    2    5    4]
#  [   7    3    4    0   12   22  904    1    5    0]
#  [   1    5   10    4    2    0    0  981    4   21]
#  [   4    2    8   10    6   13    5    2  917    7]
#  [   2    5    2    6   14    6    2    8   11  953]]
#
#
# --------------------------------------------------
# Training with Activation: sigmoid, Hidden Layer: 128
# Learning Rate: 0.1, Batch Size: 10, Epochs: 50
# --------------------------------------------------
# Epoch 1/50, Loss: 0.3449, Accuracy: 0.8989
# Epoch 2/50, Loss: 0.2625, Accuracy: 0.9211
# Epoch 3/50, Loss: 0.2216, Accuracy: 0.9329
# Epoch 4/50, Loss: 0.1946, Accuracy: 0.9413
# Epoch 5/50, Loss: 0.1752, Accuracy: 0.9463
# Epoch 6/50, Loss: 0.1600, Accuracy: 0.9512
# Epoch 7/50, Loss: 0.1476, Accuracy: 0.9549
# Epoch 8/50, Loss: 0.1369, Accuracy: 0.9581
# Epoch 9/50, Loss: 0.1276, Accuracy: 0.9607
# Epoch 10/50, Loss: 0.1192, Accuracy: 0.9630
# Epoch 11/50, Loss: 0.1116, Accuracy: 0.9651
# Epoch 12/50, Loss: 0.1047, Accuracy: 0.9676
# Epoch 13/50, Loss: 0.0983, Accuracy: 0.9697
# Epoch 14/50, Loss: 0.0924, Accuracy: 0.9718
# Epoch 15/50, Loss: 0.0870, Accuracy: 0.9734
# Epoch 16/50, Loss: 0.0820, Accuracy: 0.9752
# Epoch 17/50, Loss: 0.0773, Accuracy: 0.9768
# Epoch 18/50, Loss: 0.0729, Accuracy: 0.9783
# Epoch 19/50, Loss: 0.0688, Accuracy: 0.9797
# Epoch 20/50, Loss: 0.0649, Accuracy: 0.9812
# Epoch 21/50, Loss: 0.0613, Accuracy: 0.9824
# Epoch 22/50, Loss: 0.0580, Accuracy: 0.9836
# Epoch 23/50, Loss: 0.0549, Accuracy: 0.9847
# Epoch 24/50, Loss: 0.0521, Accuracy: 0.9857
# Epoch 25/50, Loss: 0.0494, Accuracy: 0.9864
# Epoch 26/50, Loss: 0.0470, Accuracy: 0.9872
# Epoch 27/50, Loss: 0.0447, Accuracy: 0.9878
# Epoch 28/50, Loss: 0.0426, Accuracy: 0.9885
# Epoch 29/50, Loss: 0.0406, Accuracy: 0.9894
# Epoch 30/50, Loss: 0.0388, Accuracy: 0.9899
# Epoch 31/50, Loss: 0.0370, Accuracy: 0.9905
# Epoch 32/50, Loss: 0.0354, Accuracy: 0.9911
# Epoch 33/50, Loss: 0.0339, Accuracy: 0.9916
# Epoch 34/50, Loss: 0.0325, Accuracy: 0.9920
# Epoch 35/50, Loss: 0.0311, Accuracy: 0.9925
# Epoch 36/50, Loss: 0.0299, Accuracy: 0.9929
# Epoch 37/50, Loss: 0.0287, Accuracy: 0.9932
# Epoch 38/50, Loss: 0.0275, Accuracy: 0.9937
# Epoch 39/50, Loss: 0.0265, Accuracy: 0.9939
# Epoch 40/50, Loss: 0.0255, Accuracy: 0.9941
# Epoch 41/50, Loss: 0.0245, Accuracy: 0.9944
# Epoch 42/50, Loss: 0.0236, Accuracy: 0.9946
# Epoch 43/50, Loss: 0.0227, Accuracy: 0.9949
# Epoch 44/50, Loss: 0.0219, Accuracy: 0.9952
# Epoch 45/50, Loss: 0.0211, Accuracy: 0.9954
# Epoch 46/50, Loss: 0.0203, Accuracy: 0.9955
# Epoch 47/50, Loss: 0.0196, Accuracy: 0.9958
# Epoch 48/50, Loss: 0.0189, Accuracy: 0.9961
# Epoch 49/50, Loss: 0.0183, Accuracy: 0.9962
# Epoch 50/50, Loss: 0.0177, Accuracy: 0.9964
#
# ✅ Results for Combination:
# Activation: sigmoid
# Hidden Layer: 128
# Test Accuracy: 0.9561
# Execution Time: 286.86 sec
# Confusion Matrix:
# [[ 956    0    2    0    1    9    3    3    3    3]
#  [   0 1123    3    2    1    0    0    1    5    0]
#  [   5    1  987    5    7    1    6   10    9    1]
#  [   0    2   11  958    1   13    1    6   14    4]
#  [   2    0    2    0  951    2    4    4    1   16]
#  [   6    2    1   16    2  848    4    1    8    4]
#  [   9    4    4    0   15   12  910    0    4    0]
#  [   2    6   12    6    9    2    0  971    1   19]
#  [   7    1    7    7    5    8    4    6  922    7]
#  [   5    6    3    6   29   11    1    7    6  935]]
#
#
# --------------------------------------------------
# Training with Activation: sigmoid, Hidden Layer: 64
# Learning Rate: 0.1, Batch Size: 10, Epochs: 50
# --------------------------------------------------
# Epoch 1/50, Loss: 0.3933, Accuracy: 0.8793
# Epoch 2/50, Loss: 0.3054, Accuracy: 0.9088
# Epoch 3/50, Loss: 0.2629, Accuracy: 0.9210
# Epoch 4/50, Loss: 0.2342, Accuracy: 0.9292
# Epoch 5/50, Loss: 0.2129, Accuracy: 0.9359
# Epoch 6/50, Loss: 0.1964, Accuracy: 0.9406
# Epoch 7/50, Loss: 0.1830, Accuracy: 0.9449
# Epoch 8/50, Loss: 0.1716, Accuracy: 0.9489
# Epoch 9/50, Loss: 0.1616, Accuracy: 0.9514
# Epoch 10/50, Loss: 0.1529, Accuracy: 0.9541
# Epoch 11/50, Loss: 0.1453, Accuracy: 0.9565
# Epoch 12/50, Loss: 0.1386, Accuracy: 0.9586
# Epoch 13/50, Loss: 0.1324, Accuracy: 0.9603
# Epoch 14/50, Loss: 0.1268, Accuracy: 0.9619
# Epoch 15/50, Loss: 0.1216, Accuracy: 0.9639
# Epoch 16/50, Loss: 0.1167, Accuracy: 0.9652
# Epoch 17/50, Loss: 0.1121, Accuracy: 0.9663
# Epoch 18/50, Loss: 0.1078, Accuracy: 0.9677
# Epoch 19/50, Loss: 0.1037, Accuracy: 0.9689
# Epoch 20/50, Loss: 0.0998, Accuracy: 0.9700
# Epoch 21/50, Loss: 0.0962, Accuracy: 0.9712
# Epoch 22/50, Loss: 0.0927, Accuracy: 0.9725
# Epoch 23/50, Loss: 0.0894, Accuracy: 0.9736
# Epoch 24/50, Loss: 0.0864, Accuracy: 0.9747
# Epoch 25/50, Loss: 0.0835, Accuracy: 0.9757
# Epoch 26/50, Loss: 0.0807, Accuracy: 0.9764
# Epoch 27/50, Loss: 0.0781, Accuracy: 0.9772
# Epoch 28/50, Loss: 0.0756, Accuracy: 0.9782
# Epoch 29/50, Loss: 0.0732, Accuracy: 0.9792
# Epoch 30/50, Loss: 0.0710, Accuracy: 0.9798
# Epoch 31/50, Loss: 0.0688, Accuracy: 0.9803
# Epoch 32/50, Loss: 0.0668, Accuracy: 0.9810
# Epoch 33/50, Loss: 0.0649, Accuracy: 0.9816
# Epoch 34/50, Loss: 0.0632, Accuracy: 0.9820
# Epoch 35/50, Loss: 0.0615, Accuracy: 0.9825
# Epoch 36/50, Loss: 0.0599, Accuracy: 0.9829
# Epoch 37/50, Loss: 0.0583, Accuracy: 0.9834
# Epoch 38/50, Loss: 0.0569, Accuracy: 0.9840
# Epoch 39/50, Loss: 0.0555, Accuracy: 0.9845
# Epoch 40/50, Loss: 0.0541, Accuracy: 0.9850
# Epoch 41/50, Loss: 0.0528, Accuracy: 0.9854
# Epoch 42/50, Loss: 0.0515, Accuracy: 0.9859
# Epoch 43/50, Loss: 0.0502, Accuracy: 0.9862
# Epoch 44/50, Loss: 0.0490, Accuracy: 0.9864
# Epoch 45/50, Loss: 0.0478, Accuracy: 0.9868
# Epoch 46/50, Loss: 0.0467, Accuracy: 0.9872
# Epoch 47/50, Loss: 0.0456, Accuracy: 0.9877
# Epoch 48/50, Loss: 0.0445, Accuracy: 0.9882
# Epoch 49/50, Loss: 0.0435, Accuracy: 0.9886
# Epoch 50/50, Loss: 0.0425, Accuracy: 0.9890
#
# ✅ Results for Combination:
# Activation: sigmoid
# Hidden Layer: 64
# Test Accuracy: 0.9566
# Execution Time: 222.60 sec
# Confusion Matrix:
# [[ 963    0    1    0    0    7    2    2    2    3]
#  [   0 1117    3    0    1    1    4    1    6    2]
#  [   5    7  974   17    3    3    4    6   12    1]
#  [   0    1    7  974    0   13    0    3    5    7]
#  [   4    0    1    2  939    2    7    2    5   20]
#  [   4    1    2   16    0  850    5    1    9    4]
#  [  10    2    4    2   11   11  912    1    4    1]
#  [   2    4   16    8    3    2    0  974    3   16]
#  [   7    0    7   20    4   12    5    4  906    9]
#  [   7    4    1    8   14    8    0    7    3  957]]
#
#
# --------------------------------------------------
# Training with Activation: tanh, Hidden Layer: 256
# Learning Rate: 0.1, Batch Size: 10, Epochs: 50
# --------------------------------------------------
# Epoch 1/50, Loss: 0.5214, Accuracy: 0.8978
# Epoch 49/50, Loss: 0.0020, Accuracy: 1.0000
# Epoch 50/50, Loss: 0.0019, Accuracy: 1.0000
#
# ✅ Results for Combination:
# Activation: tanh
# Hidden Layer: 256
# Test Accuracy: 0.9487
# Execution Time: 381.93 sec
# Confusion Matrix:
# [[ 965    0    2    3    0    1    4    2    1    2]
#  [   0 1111    4    2    0    1    3    3    9    2]
#  [   7    2  960   14    7    3    6   13   17    3]
#  [   1    0   12  942    2   24    0    7   17    5]
#  [   1    1    3    0  942    1    6    3    3   22]
#  [   7    0    1   20    5  836    8    2    7    6]
#  [   6    3    2    0    9   12  920    1    5    0]
#  [   0    7   10    7    8    2    0  971    4   19]
#  [   5    1    7   15    6   11    7    5  907   10]
#  [   5    4    2    6   23    7    1   10   18  933]]
#
#
# --------------------------------------------------
# Training with Activation: tanh, Hidden Layer: 128
# Learning Rate: 0.1, Batch Size: 10, Epochs: 50
# --------------------------------------------------
# Epoch 1/50, Loss: 0.4028, Accuracy: 0.8892
# Epoch 2/50, Loss: 0.2783, Accuracy: 0.9191
# Epoch 3/50, Loss: 0.2406, Accuracy: 0.9273
# Epoch 4/50, Loss: 0.2089, Accuracy: 0.9368
# Epoch 5/50, Loss: 0.1863, Accuracy: 0.9425
# Epoch 6/50, Loss: 0.1684, Accuracy: 0.9477
# Epoch 7/50, Loss: 0.1561, Accuracy: 0.9506
# Epoch 8/50, Loss: 0.1442, Accuracy: 0.9545
# Epoch 9/50, Loss: 0.1345, Accuracy: 0.9577
# Epoch 10/50, Loss: 0.1270, Accuracy: 0.9600
# Epoch 11/50, Loss: 0.1195, Accuracy: 0.9625
# Epoch 12/50, Loss: 0.1134, Accuracy: 0.9643
# Epoch 13/50, Loss: 0.1078, Accuracy: 0.9661
# Epoch 14/50, Loss: 0.1025, Accuracy: 0.9676
# Epoch 15/50, Loss: 0.0982, Accuracy: 0.9691
# Epoch 16/50, Loss: 0.0948, Accuracy: 0.9700
# Epoch 17/50, Loss: 0.0910, Accuracy: 0.9711
# Epoch 18/50, Loss: 0.0875, Accuracy: 0.9722
# Epoch 19/50, Loss: 0.0837, Accuracy: 0.9733
# Epoch 20/50, Loss: 0.0794, Accuracy: 0.9747
# Epoch 21/50, Loss: 0.0761, Accuracy: 0.9756
# Epoch 22/50, Loss: 0.0732, Accuracy: 0.9766
# Epoch 23/50, Loss: 0.0705, Accuracy: 0.9774
# Epoch 24/50, Loss: 0.0678, Accuracy: 0.9783
# Epoch 25/50, Loss: 0.0651, Accuracy: 0.9790
# Epoch 26/50, Loss: 0.0623, Accuracy: 0.9797
# Epoch 27/50, Loss: 0.0593, Accuracy: 0.9805
# Epoch 28/50, Loss: 0.0568, Accuracy: 0.9814
# Epoch 29/50, Loss: 0.0547, Accuracy: 0.9823
# Epoch 30/50, Loss: 0.0528, Accuracy: 0.9828
# Epoch 31/50, Loss: 0.0508, Accuracy: 0.9832
# Epoch 32/50, Loss: 0.0489, Accuracy: 0.9836
# Epoch 33/50, Loss: 0.0472, Accuracy: 0.9843
# Epoch 34/50, Loss: 0.0455, Accuracy: 0.9847
# Epoch 35/50, Loss: 0.0440, Accuracy: 0.9853
# Epoch 36/50, Loss: 0.0424, Accuracy: 0.9857
# Epoch 37/50, Loss: 0.0407, Accuracy: 0.9864
# Epoch 38/50, Loss: 0.0392, Accuracy: 0.9868
# Epoch 39/50, Loss: 0.0379, Accuracy: 0.9874
# Epoch 40/50, Loss: 0.0366, Accuracy: 0.9879
# Epoch 41/50, Loss: 0.0355, Accuracy: 0.9883
# Epoch 42/50, Loss: 0.0344, Accuracy: 0.9886
# Epoch 43/50, Loss: 0.0333, Accuracy: 0.9888
# Epoch 44/50, Loss: 0.0324, Accuracy: 0.9892
# Epoch 45/50, Loss: 0.0315, Accuracy: 0.9895
# Epoch 46/50, Loss: 0.0307, Accuracy: 0.9897
# Epoch 47/50, Loss: 0.0299, Accuracy: 0.9900
# Epoch 48/50, Loss: 0.0292, Accuracy: 0.9901
# Epoch 49/50, Loss: 0.0285, Accuracy: 0.9904
# Epoch 50/50, Loss: 0.0278, Accuracy: 0.9905
#
# ✅ Results for Combination:
# Activation: tanh
# Hidden Layer: 128
# Test Accuracy: 0.9396
# Execution Time: 285.17 sec
# Confusion Matrix:
# [[ 933    0    6    0    1   22    5    7    2    4]
#  [   0 1113    5    1    0    2    3    1    8    2]
#  [   6    3  973   11    9    3    4   11   11    1]
#  [   0    1   15  928    0   42    0    7    8    9]
#  [   2    1    5    0  938    5    3    4    3   21]
#  [   5    0    0   14    2  849    6    1   10    5]
#  [   7    5    9    0   12   28  893    1    3    0]
#  [   3    4   19    4    8    7    0  961    3   19]
#  [   2    2   11   17    8   33    5    7  881    8]
#  [   1    4    1    6   27   16    1   17    9  927]]
#
#
# --------------------------------------------------
# Training with Activation: tanh, Hidden Layer: 64
# Learning Rate: 0.1, Batch Size: 10, Epochs: 50
# --------------------------------------------------
# Epoch 1/50, Loss: 0.4310, Accuracy: 0.8679
# Epoch 2/50, Loss: 0.3437, Accuracy: 0.8956
# Epoch 3/50, Loss: 0.2943, Accuracy: 0.9109
# Epoch 4/50, Loss: 0.2637, Accuracy: 0.9211
# Epoch 5/50, Loss: 0.2378, Accuracy: 0.9281
# Epoch 6/50, Loss: 0.2183, Accuracy: 0.9343
# Epoch 7/50, Loss: 0.2042, Accuracy: 0.9384
# Epoch 8/50, Loss: 0.1916, Accuracy: 0.9422
# Epoch 9/50, Loss: 0.1821, Accuracy: 0.9442
# Epoch 10/50, Loss: 0.1723, Accuracy: 0.9474
# Epoch 11/50, Loss: 0.1658, Accuracy: 0.9492
# Epoch 12/50, Loss: 0.1595, Accuracy: 0.9512
# Epoch 13/50, Loss: 0.1539, Accuracy: 0.9526
# Epoch 14/50, Loss: 0.1510, Accuracy: 0.9532
# Epoch 15/50, Loss: 0.1480, Accuracy: 0.9545
# Epoch 16/50, Loss: 0.1438, Accuracy: 0.9557
# Epoch 17/50, Loss: 0.1397, Accuracy: 0.9566
# Epoch 18/50, Loss: 0.1346, Accuracy: 0.9581
# Epoch 19/50, Loss: 0.1303, Accuracy: 0.9593
# Epoch 20/50, Loss: 0.1268, Accuracy: 0.9607
# Epoch 21/50, Loss: 0.1241, Accuracy: 0.9617
# Epoch 22/50, Loss: 0.1226, Accuracy: 0.9621
# Epoch 23/50, Loss: 0.1205, Accuracy: 0.9627
# Epoch 24/50, Loss: 0.1188, Accuracy: 0.9633
# Epoch 25/50, Loss: 0.1173, Accuracy: 0.9637
# Epoch 26/50, Loss: 0.1156, Accuracy: 0.9642
# Epoch 27/50, Loss: 0.1136, Accuracy: 0.9649
# Epoch 28/50, Loss: 0.1116, Accuracy: 0.9652
# Epoch 29/50, Loss: 0.1079, Accuracy: 0.9665
# Epoch 30/50, Loss: 0.1052, Accuracy: 0.9672
# Epoch 31/50, Loss: 0.1033, Accuracy: 0.9678
# Epoch 32/50, Loss: 0.1011, Accuracy: 0.9686
# Epoch 33/50, Loss: 0.0987, Accuracy: 0.9692
# Epoch 34/50, Loss: 0.0967, Accuracy: 0.9700
# Epoch 35/50, Loss: 0.0948, Accuracy: 0.9708
# Epoch 36/50, Loss: 0.0930, Accuracy: 0.9715
# Epoch 37/50, Loss: 0.0912, Accuracy: 0.9718
# Epoch 38/50, Loss: 0.0892, Accuracy: 0.9725
# Epoch 39/50, Loss: 0.0873, Accuracy: 0.9733
# Epoch 40/50, Loss: 0.0856, Accuracy: 0.9739
# Epoch 41/50, Loss: 0.0839, Accuracy: 0.9744
# Epoch 42/50, Loss: 0.0820, Accuracy: 0.9751
# Epoch 43/50, Loss: 0.0806, Accuracy: 0.9756
# Epoch 44/50, Loss: 0.0793, Accuracy: 0.9758
# Epoch 45/50, Loss: 0.0779, Accuracy: 0.9763
# Epoch 46/50, Loss: 0.0765, Accuracy: 0.9766
# Epoch 47/50, Loss: 0.0752, Accuracy: 0.9770
# Epoch 48/50, Loss: 0.0743, Accuracy: 0.9772
# Epoch 49/50, Loss: 0.0731, Accuracy: 0.9778
# Epoch 50/50, Loss: 0.0715, Accuracy: 0.9785
#
# ✅ Results for Combination:
# Activation: tanh
# Hidden Layer: 64
# Test Accuracy: 0.9381
# Execution Time: 220.07 sec
# Confusion Matrix:
# [[ 952    1    1    0    1    7   10    3    1    4]
#  [   0 1113    1    6    0    2    3    2    8    0]
#  [  10   10  950   16    4    6    5   11   16    4]
#  [   2    3   14  940    1   22    0    7    7   14]
#  [   0    0    7    2  931    2    5    4    4   27]
#  [   4    2    1   16    4  840   10    2    7    6]
#  [  15    1    3    1   12   29  887    1    9    0]
#  [   1    5   13   10   10    4    0  948    6   31]
#  [   9    3   11   16    9   19    3    9  882   13]
#  [   3    1    0   12   30   13    0    9    3  938]]
#
#
# ✅ All combinations tested. Results saved to Google Drive: /content/drive/MyDrive/NN_Hyperparameter_Results/nn_hyperparameter_results.xlsx
